# %% [markdown]
# ### Ноутбук "Аудит, очистка и кодирование данных"

# %% [markdown]
# **Описание**: Намеренно "испорченные" синтетические данные (users, transactions) → систематический аудит → исправление (пропуски, дубли, типы, категории, выбросы) → sanity check → кодирование категорий для дальнейшего анализа.

# %%
import sys
sys.path.append("../src")

import pandas as pd
import numpy as np

from db_connection import get_engine
engine = get_engine()

from inject_messy_data import *

# %% [markdown]
# ##### Портим данные в таблице "users"

# %% [markdown]
# Запись таблицы "users" в "users_db"

# %%
users_db = pd.read_sql("SELECT * FROM users", engine)
payments_db = pd.read_sql("SELECT * FROM payments", engine)

# %% [markdown]
# Создание пропусков в ```df_users["country"]```

# %%
# df_users = make_country_nan(users_db)
# print(f'Пропусков в "country": {df_users["country"].isnull().sum()}')

# %% [markdown]
# Создание пропусков в ```df_users["signup_date"]``` где страна Испания

# %%
# df_users = make_spain_signup(df_users)
# print(f'Пропусков в "signup_date": {df_users["signup_date"].isnull().sum()}')

# %% [markdown]
# Варианты написания "Russia" в ```df_users["contry"]```

# %%
# df_users = add_country_case_variants(df_users)
# print(f'Значения в df_users["contry"]: {df_users["country"].value_counts()}')

# %% [markdown]
# Добавление дубликатов в таблицу ```"users"```

# %%
# df_users = add_duplicate_rows(users_db)
# print(f'Дубликаты в таблице "user": {df_users.duplicated().sum()}')

# %% [markdown]
# Объединений функций в одну

# %%
df_users = make_users_dirty(users_db)

# %%
print(f'Информация о "users": {df_users.info()}')
print(f'\nЗначения "country": {df_users["country"].value_counts()}')
print(f'\nДубликаты: {df_users.duplicated().sum()}')
# Out:
# <class 'pandas.DataFrame'>
# Index: 3090 entries, 0 to 313
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   3090 non-null   int64
#  1   acquisition_channel  3090 non-null   str
#  2   plan                 3090 non-null   str
#  3   country              2935 non-null   str
#  4   signup_date          2939 non-null   object
# dtypes: int64(1), object(1), str(3)
# memory usage: 209.4+ KB
# Информация о "users": None
#
# Значения "country": country
# Russia     1048
# Belarus     852
# China       433
# russia      160
# Rusia       159
# Spain       151
# RU          132
# Name: count, dtype: int64
#
# Дубликаты: 90

# %% [markdown]
# ##### Портим данные в таблице "payments"

# %%
df_payments = make_payments_dirty(payments_db)
df_payments.info()
print(f"\nПропуски в \"amount\": {df_payments['amount'].isnull().sum()}")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11096 entries, 0 to 11095
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               11096 non-null  int64
#  1   subscription_id  11096 non-null  int64
#  2   amount           10357 non-null  object
#  3   payment_date     11096 non-null  datetime64[us]
#  4   status           11096 non-null  str
# dtypes: datetime64[us](1), int64(2), object(1), str(1)
# memory usage: 433.6+ KB
#
# Пропуски в "amount": 739
